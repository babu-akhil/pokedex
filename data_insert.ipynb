# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Create the connection string
connection_string = 'postgresql://postgres:postgres@localhost:5432/pokemon'

# Create the SQLAlchemy engine
engine = create_engine(connection_string)

# %%
csv_data.rename(columns={'classfication': 'classification'}, inplace=True)
csv_data.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classification', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
basic_details_columns = ['pokedex_number', 'name', 'japanese_name', 'type1', 'type2', 'classification', 'generation', 'is_legendary']
basic_details = csv_data[basic_details_columns]
basic_details
# Out:
#      pokedex_number        name     japanese_name    type1   type2  \
# 0                 1   Bulbasaur  Fushigidaneフシギダネ    grass  poison
# 1                 2     Ivysaur   Fushigisouフシギソウ    grass  poison
# 2                 3    Venusaur  Fushigibanaフシギバナ    grass  poison
# 3                 4  Charmander      Hitokageヒトカゲ     fire     NaN
# 4                 5  Charmeleon       Lizardoリザード     fire     NaN
# ..              ...         ...               ...      ...     ...
# 796             797  Celesteela    Tekkaguyaテッカグヤ    steel  flying
# 797             798     Kartana   Kamiturugiカミツルギ    grass   steel
# 798             799    Guzzlord   Akuzikingアクジキング     dark  dragon
# 799             800    Necrozma     Necrozmaネクロズマ  psychic     NaN
# 800             801    Magearna      Magearnaマギアナ    steel   fairy
#
#           classification  generation  is_legendary
# 0           Seed Pokémon           1             0
# 1           Seed Pokémon           1             0
# ...

# %%
against_other_type_columns = [ 'against_bug',
 'against_dark',
 'against_dragon',
 'against_electric',
 'against_fairy',
 'against_fight',
 'against_fire',
 'against_flying',
 'against_ghost',
 'against_grass',
 'against_ground',
 'against_ice',
 'against_normal',
 'against_poison',
 'against_psychic',
 'against_rock',
 'against_steel',
 'against_water'
 ]

stats_columns = list(set(csv_data.columns) - (set(basic_details_columns).union(set(against_other_type_columns))))

# %%
basic_details = csv_data[basic_details_columns]
stats = csv_data[stats_columns]
against_other_type = csv_data[against_other_type_columns]

# %%
# Out:
# 801
